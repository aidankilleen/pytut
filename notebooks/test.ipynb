# %%
# Step 1 - check if printing is working
print ("is this working")
# Out:
# is this working

# %%
# Step 2 - check if I can import

from random import randint

r = randint(1, 10)

print (f"r = { r }")
# Out:
# r = 6

# %% [markdown]
# # Title
# If I want to put in text I can use "Markdown" sections
#
# ## Secondary Title
# This is a sub section
#
# ### Tertiary Title
# This is a sub-sub section
#
# * one
# * two
# * three
# * four
#
# 1. one
# 2. two
# 3. three
#
# You can make something *italics*
# You cam make something **bold**
# You can make something ~~strikethrough~~
#
# ## link
# [ucc](https://www.ucc.ie)
#
# ![UCC Banner](uccbanner.jpg)

# %%
from matplotlib import pyplot as plt

plt.plot([1, 23, 35, 22, 19, 17, 50, 8])
plt.ylabel('Test Graph')
plt.show()
